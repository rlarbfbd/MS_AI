# %%
import pandas as pd

titanicDF = pd.read_csv("./Users/stu_ict01_01/May27_1_Prerequisite/titanic.csv")

# %%
#print(titanicDF)           # 전체
print(titanicDF.shape)      # (행, 열)
print("-----------------------------")
print(titanicDF.columns)    # 필드명
print("-----------------------------")
print(titanicDF.head(5))     # 처음부터 5개
print("-----------------------------")
print(titanicDF.tail(3))     # 끝에서 3개
# Out:
# (891, 12)
# -----------------------------
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# -----------------------------
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 열 기준 조회(특정 필드만)
#print(titanicDF.Name)
#print(titanicDF["Name"])

print(titanicDF[["Name", "Age", "Survived"]])    # 여러 열 조회할 때는 리스트로 묶어서 조회
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
# 행 기준 조회(특정 데이터만)
print(titanicDF.iloc[0])     # 0번째 행 조회
print(titanicDF.iloc[0:5])     # 0번 ~ 4번 행 조회

# pandas는 원본 데이터에 영향을 주지않음

# index(찾는 기준) 기준
# 기본적으로 데이터 번호를 index로 만들어둠
# index를 이름으로 바꿈
titanicDF.set_index(titanicDF["Name"]) # 원본 데이터 변화 X
print(titanicDF)

# 만약 원본 데이터를 바꾸고 싶다면
#titanic.set_index(titanicDF["Name"]) 
#print(titanic)

print(titanicDF.loc["Braund, Mr. Owen Harris"])    # index 기준으로 조회
print(titanicDF.loc["Braund, Mr. Owen Harris" : "Heikkinen, Miss. Laina"])    # index 기준으로 조회
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# 행 + 열 기분 조회
# print(titanicDF.loc["Braund, Mr. Owen Harris"]["Age"])
#print(titanicDF.loc["Braund, Mr. Owen Harris"][["Pclass", "Age"]])
#print(titanicDF.loc["Braund, Mr. Owen Harris", ["Pclass", "Age"]])

# %%
# 조건으로 조회
# print(titanicDF["Age"])
#print(titanicDF["Age"] > 30)
#print(titanicDF[titanicDF["Age"] > 30])    # Age가 30보다 큰 데이터 조회
#print(titanicDF[titanicDF["Age"] > 30]["Age"])

# 20대 승객의 이름, 나이, 객실 등급
print((titanicDF[(titanicDF["Age"] >= 20) & (titanicDF["Age"] < 30)][["Name", "Age", "Pclass"]]))
# Out:
#                                                   Name   Age  Pclass
# 0                              Braund, Mr. Owen Harris  22.0       3
# 2                               Heikkinen, Miss. Laina  26.0       3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3
# 12                      Saundercock, Mr. William Henry  20.0       3
# 23                        Sloper, Mr. William Thompson  28.0       1
# ..                                                 ...   ...     ...
# 882                       Dahlberg, Miss. Gerda Ulrika  22.0       3
# 883                      Banfield, Mr. Frederick James  28.0       2
# 884                             Sutehall, Mr. Henry Jr  25.0       3
# 886                              Montvila, Rev. Juozas  27.0       2
# 889                              Behr, Mr. Karl Howell  26.0       1
#
# [220 rows x 3 columns]
