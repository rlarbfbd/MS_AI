# %%
# list: 기능 부족
# NumPy: 기능 추가된 리스트
# 위 둘 다 의미를 알아보기 힘듦

# Pandas(Python Data Analysis Library): 
# 실제 사용하는 pd.DataFrame: 코딩으로 하는 엑셀

# %%
import pandas as pd

# Series: 1차원 배열 (list 같은거)
a = pd.Series([123, 65, 78, 12])
print(a)
print(type(a))

# 엑셀 같은거 - 주로 사용
b = pd.DataFrame()
b["이름"] = ["홍길동", "김철수", "박영희"]
b["나이"] = [20, 30, 40]
print(b)
print(type(b))
# Out:
# 0    123
# 1     65
# 2     78
# 3     12
# dtype: int64
# <class 'pandas.core.series.Series'>
#     이름  나이
# 0  홍길동  20
# 1  김철수  30
# 2  박영희  40
# <class 'pandas.core.frame.DataFrame'>

# %%
# csv(첫 줄이 필드명) -> pd.DataFrame
titanicDF = pd.read_csv("./Users/stu_ict01_01/May27_1_Prerequisite/titanic.csv")
print(titanicDF)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# csv(첫 줄부터 데이터) -> pd.DataFrame
import pandas as pd

subwayDF = pd.read_csv("./Users/stu_ict01_01/May27_1_Prerequisite/subway.csv", 
                       names=["년", "월", "일", "노선", "역명", "승차인원", "하차인원"])
print(subwayDF)
# Out:
#             년   월   일   노선    역명   승차인원   하차인원
# 0        2015   1   1  1호선   서울역  47071  40197
# 1        2015   1   1  1호선    시청  11016   8943
# 2        2015   1   1  1호선    종각  22084  17648
# 3        2015   1   1  1호선  종로3가  17917  15817
# 4        2015   1   1  1호선  종로5가   9789   9216
# ...       ...  ..  ..  ...   ...    ...    ...
# 2143338  2024  12  31  중앙선    오빈    275    289
# 2143339  2024  12  31  중앙선    양평   3110   3426
# 2143340  2024  12  31  중앙선    원덕    307    294
# 2143341  2024  12  31  중앙선    용문   1751   1947
# 2143342  2024  12  31  중앙선    지평     52     76
#
# [2143343 rows x 7 columns]

# %%
from http.client import HTTPConnection
from json import loads

# JSON
hc = HTTPConnection("openapi.seoul.go.kr:8088")
hc.request("GET", "/575a4655496b636839386f58586542/json/RealtimeCityAir/1/25/")
resBody = hc.getresponse().read()
print(resBody.decode())

airData = loads(resBody)
airData2 = airData["RealtimeCityAir"]["row"]

# Python list + dict
airDF = pd.DataFrame(airData2)
print(airDF)
# Out:
# {"RealtimeCityAir":{"list_total_count":25,"RESULT":{"CODE":"INFO-000","MESSAGE":"정상 처리되었습니다"},"row":[{"MSRMT_DT":"202605271600","SAREA_NM":"도심권","MSRSTN_NM":"중구","PM":26.0,"FPM":18.0,"OZON":0.019,"NTDX":0.016,"CBMX":0.4,"SPDX":0.002,"CAI_GRD":"보통","CAI_IDX":54.0,"CRST_SBSTN":"PM-2.5"},{"MSRMT_DT":"202605271600","SAREA_NM":"도심권","MSRSTN_NM":"종로구","PM":29.0,"FPM":14.0,"OZON":0.028,"NTDX":0.013,"CBMX":0.4,"SPDX":0.003,"CAI_GRD":"좋음","CAI_IDX":50.0,"CRST_SBSTN":"PM-2.5"},{"MSRMT_DT":"202605271600","SAREA_NM":"도심권","MSRSTN_NM":"용산구","PM":24.0,"FPM":15.0,"OZON":0.027,"NTDX":0.013,"CBMX":0.3,"SPDX":0.002,"CAI_GRD":"보통","CAI_IDX":59.0,"CRST_SBSTN":"PM-2.5"},{"MSRMT_DT":"202605271600","SAREA_NM":"서북권","MSRSTN_NM":"은평구","PM":21.0,"FPM":17.0,"OZON":0.035,"NTDX":0.008,"CBMX":0.5,"SPDX":0.002,"CAI_GRD":"보통","CAI_IDX":54.0,"CRST_SBSTN":"O3"},{"MSRMT_DT":"202605271600","SAREA_NM":"서북권","MSRSTN_NM":"서대문구","PM":0.0,"FPM":0.0,"OZON":0.0,"NTDX":0.0,"CBMX":0.0,"SPDX":0.0,"CAI_GRD":"","CAI_IDX":0.0,"CRST
# ...

# %%
# RDBMS의 데이터 -> pd.DataFrame
# !리눅스 명령어 or %리눅스명령어 -> 터미널에서 실행
# !리눅스 명령어: 새 putty 열어서 실행하고 날리기 -> 임시명령어(간단하고 확인할 때)
# %리눅스 명령어: 리눅스 서버에 실제로 뭔가 세팅(설치할 때)
# %pip install oracledb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 34.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from oracledb import connect

con = connect("rosalie/fbdrbrla123@202.31.246.27:1521/xe")
sql = "SELECT * FROM may26_snack"

snackDF = pd.read_sql(sql, con)

print(snackDF)

con.close()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File src/oracledb/impl/thin/connection.pyx:421, in oracledb.thin_impl.ThinConnImpl._connect_with_address()
#
# File src/oracledb/impl/thin/protocol.pyx:268, in oracledb.thin_impl.Protocol._connect_phase_one()
#
# File src/oracledb/impl/thin/protocol.pyx:402, in oracledb.thin_impl.Protocol._connect_tcp()
#
# File /anaconda/envs/jupyter_env/lib/python3.10/socket.py:857, in create_connection(address, timeout, source_address)
#     856 try:
# --> 857     raise err
#     858 finally:
#     859     # Break explicitly a reference cycle
#
# File /anaconda/envs/jupyter_env/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# ...
