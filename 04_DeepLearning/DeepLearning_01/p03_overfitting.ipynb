# %%
# overfitting
#   훈련 데이터에만 너무 딱 맞게 학습되어서 훈련 데이터에 없는거 물어보면 오차 폭발

# data augmentation
#   일부러 훈련 데이터에 변형을 가해서 (사진이면 뒤집고 색 바꾸고...)

# dropout: 랜덤하게 노드를 가려가면서 학습
#   첫 데이터 학습할 때 랜덤하게 노드 1/3개 가려서 학습
#   ...
# dropconnection: 랜덤하게 연결을 가려가면서 학습
# -> 최종 실 사용할 때는 다 살려서
