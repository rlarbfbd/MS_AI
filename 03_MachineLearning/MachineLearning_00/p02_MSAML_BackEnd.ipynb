# %%
# %pip install mlflow
# %pip install azureml-mlflow
# mlflow: 만든 AI 모델을 파일로 저장해주는 라이브러리
# azureml-mlflow: AzureML + mlflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 83.4 MB/s  0:00:00
# ...
#   Attempting uninstall: msal
#     Found existing installation: msal 1.34.0
#     Uninstalling msal-1.34.0:
#       Successfully uninstalled msal-1.34.0
#   Attempting uninstall: mlflow-skinny
#     Found existing installation: mlflow-skinny 3.12.0
#     Uninstalling mlflow-skinny-3.12.0:
#       Successfully uninstalled mlflow-skinny-3.12.0━━━━━━━━━━━━━━━ 1/4 [mlflow-skinny]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [azureml-mlflow]m [azureml-mlflow]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.12.0 requires mlflow-skinny==3.12.0, but you have mlflow-skinny 3.9.0 which is incompatible.
# ...

# %%
# 1) mlflow써서 만든 모델 저장
# 2) mlflow 실행 후 생긴 폴더에 가면 conda.yaml에 추가
'''
- pip부분에
 - azureml-ai-monitoring
 - azureml-inference-server-http
 - inference-schema
'''
# 3) 폴더 통으로 다운로드
# 4) ml.azure.com
# 5) 모델 -> 등록
# 6) 등록된 모델들어가서 ~~
# 7) 완료 후 테스트
'''
{
    "input_data": {
        "columns": ["fight", "yok"],
        "index": [0],
        "data": [[80, 20]]                  # 물어보고 싶은거
    },
    "params": {}
}
'''
# 8) 활용 -> 사용 탭에서 코드 복사해서
