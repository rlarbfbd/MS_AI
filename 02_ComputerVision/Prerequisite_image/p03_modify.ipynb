# %%
# overfitting(과적합): 훈련 데이터에 너무 딱 맞게 되어있어 새로운 것을 예측을 못하는 것
# 학습 데이터 양 부족

# 과적합 문제 해결 + 부족한 데이터 양
# -> Data Augmentation(증강): 일부러 데이터를 변형시켜 가면서 데이터를 더 만들어서 사용

# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 34.3 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 69.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 35.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [matplotlib]6 [matplotlib]
# ...

# %%
import cv2
import matplotlib.pyplot as plt

a = cv2.imread("./Users/stu_ict01_01/May28_2_Prerequisite_image/134093712144418504.jpg", cv2.IMREAD_GRAYSCALE)

b = a[10:20, 30:50]                         # 부분만 잘라내기
#print(b)

c = cv2.rotate(a, cv2.ROTATE_90_CLOCKWISE)

d = cv2.resize(a, dsize=(0, 0), fx=0.5, fy=0.5)           # dsize에 값을 직접 넣을 수도 있지만 사진 비율이 깨짐 / 가로세로 50%

plt.imshow(d)
plt.show()
