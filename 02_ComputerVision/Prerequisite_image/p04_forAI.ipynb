# %% [markdown]
# 인공신경망: 회귀분석 + 행렬계산
#
# 흑백 이미지 -> 2차원 리스트
# 컬러 이미지 -> 3차원 리스트
# 영상 -> 4차원 리스트
#
# 차원 수를 1차원으로 줄이자

# %%
import cv2
# import matplotlib.pyplot as plt

a = cv2.imread("./Users/stu_ict01_01/May28_2_Prerequisite_image/134093712144418504.jpg", cv2.IMREAD_COLOR)

b = a.flatten()                 # 1차원으로 줄이기
print(b)
print(len(b))
# Out:
# [162 111 149 ... 164 108 129]
# 24883200

# %% [markdown]
# 1. TensorFlow/ PyTorch에 자체적으로 기능 존재
# 2. 다차원 리스트를 냅다 1차원으로 펴면 ?? -> CNN
