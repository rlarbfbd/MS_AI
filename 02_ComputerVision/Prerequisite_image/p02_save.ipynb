# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

a = cv2.imread("./Users/stu_ict01_01/May28_2_Prerequisite_image/134093712144418504.jpg", cv2.IMREAD_GRAYSCALE)
print(a)

# Python 시각화 라이브러리: Matplotlib
import matplotlib.pyplot as plt

plt.imshow(a)
# Out:
# [[128 129 129 ... 135 125 125]
#  [129 126 128 ... 127 116 123]
#  [131 127 126 ... 128 116 122]
#  ...
#  [128 135 118 ... 122 129 126]
#  [128 131 121 ... 126 123 114]
#  [126 129 120 ... 127 126 121]]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 print(a)
#       6 # Python 시각화 라이브러리: Matplotlib
# ----> 7 import matplotlib.pyplot as plt
#       9 plt.imshow(a)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# 이미지 저장
cv2.imwrite("./Users/stu_ict01_01/May28_2_Prerequisite_image/134093712144418504_2.jpg", a)
# Out:
# True
